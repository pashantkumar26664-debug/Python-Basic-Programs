# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve','Frank','Grace', 'Hannah'],
    'Age': [25, 30, 35, 28, 32, 27, 31, 29],
    'Marks': [85, 90, 78, 88, 92, 80, 87, 95],
    'City': ['New York', 'London', 'Paris', 'Berlin', 'Tokyo', 'Sydney', 'Rome', 'Madrid'],
    'Gender': ['F', 'M', 'M', 'M', 'F','M','F','F']
})
df
# Out:
#       Name  Age  Marks      City Gender
# 0    Alice   25     85  New York      F
# 1      Bob   30     90    London      M
# 2  Charlie   35     78     Paris      M
# 3    David   28     88    Berlin      M
# 4      Eve   32     92     Tokyo      F
# 5    Frank   27     80    Sydney      M
# 6    Grace   31     87      Rome      F
# 7   Hannah   29     95    Madrid      F

# %%
#pandas functions used for dataframes

df.head(2)
df.tail(2)  
df.describe()
df.info()
df.shape
df.columns
df['Age'].sum()
df.to_csv('students.csv', index=True)
df.loc[2]       # Access row with index 2
df.loc[1:4]   # Access rows from index 1 to 3
df.loc[df['Age'] > 30]  # Filter rows where Age is greater than 30
df.Age.mean()  # Calculate the mean of the Age column
df1=df.copy() # Create a copy of the DataFrame
df.loc[5, 'Age'] = 22  # Modify value at row index 5 and column 'Age'
df.iloc[0:3, 0:2]  # Access rows 0 to 2 and columns 0 to 1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    8 non-null      object
#  1   Age     8 non-null      int64
#  2   Marks   8 non-null      int64
#  3   City    8 non-null      object
#  4   Gender  8 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 452.0+ bytes
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df1 = pd.read_csv('output.csv')    #importing csv file as dataframe
df1
# Out:
#            0         1         2         3         4
# 0   0.612672  0.408426  0.443078  0.211117  0.138875
# 1   0.075550  0.252768  0.839863  0.300525  0.273163
# 2   0.637870  0.375703  0.300417  0.170522  0.830191
# 3   0.734881  0.700873  0.797769  0.561666  0.594527
# 4   0.283408  0.755487  0.571437  0.573206  0.844968
# 5   0.254142  0.364775  0.356299  0.153771  0.591565
# 6   0.756397  0.861971  0.389499  0.870755  0.797986
# 7   0.548808  0.586186  0.597586  0.564516  0.258193
# 8   0.976534  0.445745  0.236671  0.255028  0.170098
# 9   0.887212  0.842015  0.955741  0.839703  0.477758
# 10  0.494608  0.118892  0.941710  0.748787  0.493669
# 11  0.322968  0.221322  0.577683  0.698392  0.069115
# 12  0.695640  0.746115  0.619714  0.395222  0.762216
# 13  0.466841  0.720019  0.644492  0.189865  0.958284
# 14  0.575008  0.172856  0.727222  0.626922  0.297179
# 15  0.856801  0.387068  0.627549  0.812803  0.380715
# 16  0.401056  0.507234  0.975253  0.575073  0.434511
# ...

# %%
df1['1']
# Out:
# 0     0.408426
# 1     0.252768
# 2     0.375703
# 3     0.700873
# 4     0.755487
# 5     0.364775
# 6     0.861971
# 7     0.586186
# 8     0.445745
# 9     0.842015
# 10    0.118892
# 11    0.221322
# 12    0.746115
# 13    0.720019
# 14    0.172856
# 15    0.387068
# 16    0.507234
# 17    0.136583
# 18    0.513716
# 19    0.239325
# 20    0.020506
# 21    0.491555
# 22    0.456694
# 23    0.777413
# 24    0.968145
# 25    0.706312
# 26    0.704634
# 27    0.935106
# 28    0.046640
# 29    0.034801
# 30    0.779869
# 31    0.683310
# 32    0.804032
# 33    0.439310
# 34    0.668329
# 35    0.783156
# 36    0.625111
# 37    0.136403
# 38    0.535601
# 39    0.434851
# 40    0.740221
# 41    0.232134
# 42    0.253201
# 43    0.785803
# 44    0.937262
# 45    0.519695
# 46    0.142996
# 47    0.586729
# 48    0.295610
# 49    0.517041
# Name: 1, dtype: float64

# %%
df1.drop('1', axis=1, inplace=True)
df1

# %%
df.dropna(inplace=True)  #drops rows with any NaN values
df.fillna(0, inplace=True)  #fills NaN values with 0
df

# %%
newse=pd.DataFrame(np.random.rand(15,5), index=range(51,66), columns=['A','B','C','D','E'])
newse
# creating dataframe from random values

# %%
pd1=pd.concat([df1, newse], axis=0)  #concatenating dataframes row-wise
pd1
# Out:
#            0         2         3         4         A         B         C  \
# 0   0.612672  0.443078  0.211117  0.138875       NaN       NaN       NaN
# 1   0.075550  0.839863  0.300525  0.273163       NaN       NaN       NaN
# 2   0.637870  0.300417  0.170522  0.830191       NaN       NaN       NaN
# 3   0.734881  0.797769  0.561666  0.594527       NaN       NaN       NaN
# 4   0.283408  0.571437  0.573206  0.844968       NaN       NaN       NaN
# ..       ...       ...       ...       ...       ...       ...       ...
# 61       NaN       NaN       NaN       NaN  0.889644  0.315614  0.662182
# 62       NaN       NaN       NaN       NaN  0.578785  0.727255  0.702619
# 63       NaN       NaN       NaN       NaN  0.446730  0.311096  0.553852
# 64       NaN       NaN       NaN       NaN  0.502051  0.218212  0.814564
# 65       NaN       NaN       NaN       NaN  0.333456  0.136476  0.277792
#
#            D         E
# 0        NaN       NaN
# 1        NaN       NaN
# ...

# %%
pd1.notnull()  #checking for non null values in dataframe
# Out:
#         0      2      3      4      A      B      C      D      E
# 0    True   True   True   True  False  False  False  False  False
# 1    True   True   True   True  False  False  False  False  False
# 2    True   True   True   True  False  False  False  False  False
# 3    True   True   True   True  False  False  False  False  False
# 4    True   True   True   True  False  False  False  False  False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 61  False  False  False  False   True   True   True   True   True
# 62  False  False  False  False   True   True   True   True   True
# 63  False  False  False  False   True   True   True   True   True
# 64  False  False  False  False   True   True   True   True   True
# 65  False  False  False  False   True   True   True   True   True
#
# [65 rows x 9 columns]

# %%
pd1.to_csv('concatinate.csv', index=True)

# %%
pd1.dropna()  #drops rows with any NaN values
# Out:
# Empty DataFrame
# Columns: [0, 2, 3, 4, A, B, C, D, E]
# Index: []

# %%
pd1.fillna(0)  #fill na values with 0
# Out:
#            0         2         3         4         A         B         C  \
# 0   0.612672  0.443078  0.211117  0.138875  0.000000  0.000000  0.000000
# 1   0.075550  0.839863  0.300525  0.273163  0.000000  0.000000  0.000000
# 2   0.637870  0.300417  0.170522  0.830191  0.000000  0.000000  0.000000
# 3   0.734881  0.797769  0.561666  0.594527  0.000000  0.000000  0.000000
# 4   0.283408  0.571437  0.573206  0.844968  0.000000  0.000000  0.000000
# ..       ...       ...       ...       ...       ...       ...       ...
# 61  0.000000  0.000000  0.000000  0.000000  0.889644  0.315614  0.662182
# 62  0.000000  0.000000  0.000000  0.000000  0.578785  0.727255  0.702619
# 63  0.000000  0.000000  0.000000  0.000000  0.446730  0.311096  0.553852
# 64  0.000000  0.000000  0.000000  0.000000  0.502051  0.218212  0.814564
# 65  0.000000  0.000000  0.000000  0.000000  0.333456  0.136476  0.277792
#
#            D         E
# 0   0.000000  0.000000
# 1   0.000000  0.000000
# ...

# %%
pd1
# Out:
#            0         2         3         4         A         B         C  \
# 0   0.612672  0.443078  0.211117  0.138875       NaN       NaN       NaN
# 1   0.075550  0.839863  0.300525  0.273163       NaN       NaN       NaN
# 2   0.637870  0.300417  0.170522  0.830191       NaN       NaN       NaN
# 3   0.734881  0.797769  0.561666  0.594527       NaN       NaN       NaN
# 4   0.283408  0.571437  0.573206  0.844968       NaN       NaN       NaN
# 5   0.254142  0.356299  0.153771  0.591565       NaN       NaN       NaN
# 6   0.756397  0.389499  0.870755  0.797986       NaN       NaN       NaN
# 7   0.548808  0.597586  0.564516  0.258193       NaN       NaN       NaN
# 8   0.976534  0.236671  0.255028  0.170098       NaN       NaN       NaN
# 9   0.887212  0.955741  0.839703  0.477758       NaN       NaN       NaN
# 10  0.494608  0.941710  0.748787  0.493669       NaN       NaN       NaN
# 11  0.322968  0.577683  0.698392  0.069115       NaN       NaN       NaN
# ...

# %%
pd1.loc[2,'B']=100
pd1
# Out:
#            0         2         3         4         A           B         C  \
# 0   0.612672  0.443078  0.211117  0.138875       NaN         NaN       NaN
# 1   0.075550  0.839863  0.300525  0.273163       NaN         NaN       NaN
# 2   0.637870  0.300417  0.170522  0.830191       NaN  100.000000       NaN
# 3   0.734881  0.797769  0.561666  0.594527       NaN         NaN       NaN
# 4   0.283408  0.571437  0.573206  0.844968       NaN         NaN       NaN
# 5   0.254142  0.356299  0.153771  0.591565       NaN         NaN       NaN
# 6   0.756397  0.389499  0.870755  0.797986       NaN         NaN       NaN
# 7   0.548808  0.597586  0.564516  0.258193       NaN         NaN       NaN
# 8   0.976534  0.236671  0.255028  0.170098       NaN         NaN       NaN
# 9   0.887212  0.955741  0.839703  0.477758       NaN         NaN       NaN
# 10  0.494608  0.941710  0.748787  0.493669       NaN         NaN       NaN
# ...

# %%
# use inplace=True to make changes in original dataframe
pd1.fillna(1, inplace=True)
pd1
# Out:
#            0         2         3         4         A           B         C  \
# 0   0.612672  0.443078  0.211117  0.138875  1.000000    1.000000  1.000000
# 1   0.075550  0.839863  0.300525  0.273163  1.000000    1.000000  1.000000
# 2   0.637870  0.300417  0.170522  0.830191  1.000000  100.000000  1.000000
# 3   0.734881  0.797769  0.561666  0.594527  1.000000    1.000000  1.000000
# 4   0.283408  0.571437  0.573206  0.844968  1.000000    1.000000  1.000000
# 5   0.254142  0.356299  0.153771  0.591565  1.000000    1.000000  1.000000
# 6   0.756397  0.389499  0.870755  0.797986  1.000000    1.000000  1.000000
# 7   0.548808  0.597586  0.564516  0.258193  1.000000    1.000000  1.000000
# 8   0.976534  0.236671  0.255028  0.170098  1.000000    1.000000  1.000000
# 9   0.887212  0.955741  0.839703  0.477758  1.000000    1.000000  1.000000
# 10  0.494608  0.941710  0.748787  0.493669  1.000000    1.000000  1.000000
# ...
