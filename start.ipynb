# %%
import matplotlib.pyplot as plt     #pyplot api use here 
import pandas as pd

# %%
#plot graph

x=[1,2,3]
y=[4,5,6]
plt.plot(x,y)
plt.grid()
plt.show()

# %%
data={'semesters' : [1, 2, 3, 4, 5, 6],'cgpa' : [7.0,7.5,7.2,7.4,7.9,7.3]}
df=pd.DataFrame(data)
plt.plot(semesters,cgpa,color="Blue",marker='o')
plt.xlabel('Semester')
plt.ylabel('CGPA')
plt.title('CGPA by Semester')
plt.grid()
plt.show()

# %%
plt.boxplot(df)
plt.show()
